# %% [markdown]
# ### Imports and Definitions

# %%
from gzip import open as gopen
from math import log10
from matplotlib.patches import Patch
from os.path import isfile
from pickle import load,dump
from random import shuffle
from treeswift import read_tree_newick
import matplotlib.pyplot as plt
import seaborn as sns
TN93THRESH = 0.015

# %% [markdown]
# ### Helper Function to Load FASTA

# %%
def read_FASTA(filename):
    seqs = {}
    name = None
    seq = ''
    if filename.lower().endswith('.gz'):
        f = gopen(filename)
    else:
        f = open(filename)
    for line in f:
        if isinstance(line,bytes):
            l = line.decode().strip()
        else:
            l = line.strip()
        if len(l) == 0:
            continue
        if l[0] == '>':
            if name is not None:
                assert len(seq) != 0, "Malformed FASTA"
                seqs[name] = seq
            name = l[1:]
            assert name not in seqs, "Duplicate sequence ID: %s" % name
            seq = ''
        else:
            seq += l
    f.close()
    assert name is not None and len(seq) != 0, "Malformed FASTA"
    seqs[name] = seq
    return seqs

# %% [markdown]
# ### Helper Function to Load tn93 Output as Distance Matrix

# %%
def read_tn93(filename):
    dm = dict()
    if filename.lower().endswith('.gz'):
        f = gopen(filename)
    else:
        f = open(filename)
    for line in f:
        if isinstance(line,bytes):
            l = line.decode().strip()
        else:
            l = line.strip()
        u,v,d = l.split(',')
        if d == 'Distance':
            continue
        d = float(d)
        if u not in dm:
            dm[u] = dict()
        if v not in dm:
            dm[v] = dict()
        dm[u][v] = d; dm[v][u] = d
    return dm

# %% [markdown]
# ### Helper Functions to Compute Cumulative Moving Average

# %%
# compute the average of a list of numbers
def avg(x):
    if len(x) == 0:
        return 0
    return sum(x)/len(x)

# get the Cumulative Moving Average (CMA) over all indices
def cma(x):
    y = [x[0]]
    for i in range(1,len(x)):
        y.append(y[-1]+x[i])
    for i in range(len(y)):
        y[i] /= (i+1)
    return y

# helper function to compute the test statistic
def cma_test_stat(y,normalize=False):
    if normalize:
        sum_miny = sum(cma(sorted(x)))
        return (sum(y)-sum_miny)/(sum(cma(sorted(x,reverse=True)))-sum_miny) # AUC of CMA, normalized so min = 0 and max = 1
    else:
        return sum(y) # AUC of CMA

# returns (stat,p,cma_dist,stat_dist). "side" is "left" or "right"
def cma_test(x,side,it=1000):
    assert side in {'left','right'}, "'side' must be 'left' or 'right'"
    y = cma(x)
    stat = cma_test_stat(y)
    cma_dist = list(); stat_dist = list()
    for _ in range(it):
        tmp = x[:]; shuffle(tmp); tmp_cma = cma(tmp)
        cma_dist.append(tmp_cma)
        stat_dist.append(cma_test_stat(tmp_cma))
    if side == 'right':
        p = sum(e >= stat for e in stat_dist)/len(stat_dist)
    elif side == 'left':
        p = sum(e <= stat for e in stat_dist)/len(stat_dist)
    return stat,p,cma_dist,stat_dist

# %% [markdown]
# ### Helper Functions to Compute Pairwise Probability Test

# %%
# compute the pairwise probability score
def pairprob(om,num):
    c = 0.; n = 0.
    if num is None: # compare each i-th person against each (j>i)-th person
        bins = dict()
        for i,e in reversed(list(enumerate(om))):
            if e not in bins:
                bins[e] = list()
            bins[e].append(i)
        vals = sorted(bins.keys(),reverse=True)
        for vi in range(len(vals)-1):
            for vj in range(vi+1,len(vals)):
                n += len(bins[vals[vi]])*len(bins[vals[vj]])
                for i in bins[vals[vi]]:
                    for j in bins[vals[vj]]:
                        if i < j:
                            c += 1
    else: # compare each (i<num)-th person against each (j>=num)-th person
        pass
    return c/n

# helper function to compute the test statistic
def pairprob_stat(om,num):
    return pairprob(om,num)

# returns (stat,p,stat_dist)
def pairprob_test(om,num,side,it=1000):
    assert side in {'left','right'}, "'side' must be 'left' or 'right'"
    pp = pairprob_stat(om,num)
    pp_dist = list()
    for _ in range(it):
        tmp = om[:]; shuffle(tmp); pp_dist.append(pairprob_stat(tmp,num))
    if side == 'right':
        p = sum(e >= pp for e in pp_dist)/len(pp_dist)
    elif side == 'left':
        p = sum(e <= pp for e in pp_dist)/len(pp_dist)
    return pp,p,pp_dist

# %% [markdown]
# ### Load Data

# %%
data = {
    'seqs': read_FASTA('../real_data/sd.full.aln.gz'),
    'tn93': read_tn93('../real_data/sd.full.tn93.csv.gz'),
    'time': {t:{l.decode().strip().split()[0]:int(l.decode().strip().split()[1]) for l in gopen('../real_data/sd.time.%s.tsv.gz'%t)} for t in ['sample','diagnosis','infection']},
    'proact': {n:{t:{s:{m:gopen('../real_data/sd.%s.%s.mv.proact.%s.%s.txt.gz'%(n,t,s,m)).read().decode().strip().splitlines() for m in ['feedback','oldmode']} for s in ['sample']} for t in ['ft','iq']} for n in ['10','20','30','40','50','60','70','80','90','full']}
}
meta = {
    'label': {
        'ft': 'FastTree',
        'iq': 'IQ-TREE',
        'feedback': 'ProACT (Feedback)',
        'oldmode': 'ProACT (No Feedback)',
        'max': 'Optimal',
        'bg': 'Background'
    }
}

# %% [markdown]
# ## Metric: 1/(average time between me and HIV-TRACE link)

# %% [markdown]
# ### Cumulative Moving Average (CMA) Test

# %%
IT = 1000
for t in ['ft','iq']:
    for per in ['50']: # only doing median
        END = max(int(l.split('_')[-1]) for l in data['proact'][per]['ft']['sample']['feedback'])
        for s in ['sample']:
            fig = plt.figure()
            x = list(range(len(data['proact'][per][t][s]['feedback'])))
            pronew = [avg([data['time'][s][v]-data['time'][s][u] for v in data['tn93'][u] if data['tn93'][u][v] <= TN93THRESH and data['time'][s][v] > END]) if u in data['tn93'] else 0 for u in data['proact'][per][t][s]['feedback']]
            pronew = [0 if e == 0 else 1./e for e in pronew]
            pronew_y = cma(pronew)
            pronew_stat,pronew_p,cma_dist,stat_dist = cma_test(pronew,'right',it=IT)
            pronew_pstr = "{:.{}f}".format(pronew_p,int(log10(IT)))
            proold = [avg([data['time'][s][v]-data['time'][s][u] for v in data['tn93'][u] if data['tn93'][u][v] <= TN93THRESH and data['time'][s][v] > END]) if u in data['tn93'] else 0 for u in data['proact'][per][t][s]['oldmode']]
            proold = [0 if e == 0 else 1./e for e in proold]
            proold_y = cma(proold)
            proold_stat,proold_p,cma_dist,stat_dist = cma_test(proold,'right',it=IT)
            proold_pstr = "{:.{}f}".format(proold_p,int(log10(IT)))
            opt_y = cma(sorted(pronew,reverse=True))
            for bg in cma_dist[:min(len(cma_dist),1000)]: # background distribution
                plt.plot(x,bg,color='lightgrey',linewidth=0.5)
            plt.plot(x,cma_dist[0],color='lightgrey',linewidth=0.5,label=meta['label']['bg'])
            plt.plot(x,proold_y,color='red',linewidth=2,label=r"%s, $p = %s$"%(meta['label']['oldmode'],proold_pstr)) # ProACT oldmode result
            plt.plot(x,pronew_y,color='green',linewidth=2,label=r"%s, $p = %s$"%(meta['label']['feedback'],pronew_pstr)) # ProACT feedback result
            plt.plot(x,opt_y,color='blue',linewidth=2,label=meta['label']['max']) # max possible
            plt.xlim(xmin=0,xmax=max(x))
            plt.ylim(ymin=0)
            handles,labels = fig.gca().get_legend_handles_labels()
            plt.legend(handles[::-1],labels[::-1])
            plt.title("CMA Test (%s)"%meta['label'][t])
            plt.xlabel("Individuals (ProACT Order)")
            plt.ylabel("1/(average time to next link)")
            fig.savefig('results.cmatest.%s.pdf'%t, format='pdf', bbox_inches='tight')

# %% [markdown]
# ### Pairwise Probability Test

# %%
IT = 1000
for t in ['ft','iq']:
    for s in ['sample']:
        fig = plt.figure()
        x = list(); y = list(); hue = list(); pal = list(); tmp = list(); pal = ['lightgrey']
        for m in ['feedback','oldmode']:
            print("%s, %s"%(meta['label'][m],meta['label'][t]))
            for per in ['10','20','30','40','50','60','70','80','90']:
                END = max(int(l.split('_')[-1]) for l in data['proact'][per]['ft']['sample']['feedback'])
                val = [avg([data['time'][s][v]-data['time'][s][u] for v in data['tn93'][u] if data['tn93'][u][v] <= TN93THRESH and data['time'][s][v] > END]) if u in data['tn93'] else 0 for u in data['proact'][per][t][s][m]]
                val = [0 if e == 0 else 1./e for e in val]
                pp,p,pp_dist = pairprob_test(val,None,'right',it=IT)
                pstr = "{:.{}f}".format(p,int(log10(IT)))
                #xstr = r"%s ($p=%s$)"%(per,pstr)
                print("%s-th Percentile: p = %s" % (per,p))
                for bg in pp_dist:
                    x.append(per); y.append(bg); hue.append(meta['label']['bg'])
                if m == 'oldmode':
                    tmp.append((per,pp,meta['label'][m],'red'))
                else:
                    tmp.append((per,pp,meta['label'][m],'green'))
            print()
        for per,pp,h,c in tmp:
            x.append(per); y.append(pp); hue.append(h)
            if c not in pal:
                pal.append(c)
        sns.stripplot(x=x,y=y,hue=hue,palette=pal,jitter=True)
        handles,labels = fig.gca().get_legend_handles_labels()
        plt.legend(handles[::-1],labels[::-1])
        plt.title("Pairwise Probability Test (%s)"%meta['label'][t])
        plt.xlabel("Percentile")
        plt.ylabel("Pairwise Probability")
        fig.savefig('results.pairprobtest.%s.pdf'%t, format='pdf', bbox_inches='tight')
# Out:
# ProACT (Feedback), FastTree
# 10-th Percentile: p = 0.0
# 20-th Percentile: p = 0.194
# 30-th Percentile: p = 0.002
# 40-th Percentile: p = 0.0
# 50-th Percentile: p = 0.313
# 60-th Percentile: p = 0.0
# 70-th Percentile: p = 0.0
# 80-th Percentile: p = 0.0
# 90-th Percentile: p = 0.0
#
# ProACT (No Feedback), FastTree
# 10-th Percentile: p = 0.0
# 20-th Percentile: p = 0.0
# 30-th Percentile: p = 0.0
# 40-th Percentile: p = 0.0
# 50-th Percentile: p = 0.0
# 60-th Percentile: p = 0.0
# 70-th Percentile: p = 0.0
# 80-th Percentile: p = 0.0
# 90-th Percentile: p = 0.0
#
# ProACT (Feedback), IQ-TREE
# 10-th Percentile: p = 0.0
# 20-th Percentile: p = 0.255
# 30-th Percentile: p = 0.0
# 40-th Percentile: p = 0.0
# 50-th Percentile: p = 0.574
# 60-th Percentile: p = 0.001
# 70-th Percentile: p = 0.0
# 80-th Percentile: p = 0.0
# 90-th Percentile: p = 0.0
#
# ProACT (No Feedback), IQ-TREE
# 10-th Percentile: p = 0.0
# 20-th Percentile: p = 0.0
# 30-th Percentile: p = 0.002
# 40-th Percentile: p = 0.0
# 50-th Percentile: p = 0.0
# 60-th Percentile: p = 0.0
# 70-th Percentile: p = 0.0
# 80-th Percentile: p = 0.0
# 90-th Percentile: p = 0.0
